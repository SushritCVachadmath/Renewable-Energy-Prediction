# %%
import pandas as pd
import numpy as np


import lazypredict
from lazypredict.Supervised import LazyRegressor


import matplotlib.pyplot as plt

from utility_functions import metrics

import warnings
warnings.filterwarnings("ignore")

# %%
weather = pd.read_csv('Dataset_weather.csv',parse_dates=[0], index_col=0)

# %%
weather
# Out:
#                            DE_wind_generation_actual  \
# utc_timestamp
# 2016-01-01 00:00:00+00:00                    8579.00
# 2016-01-01 01:00:00+00:00                    8542.00
# 2016-01-01 02:00:00+00:00                    8443.00
# 2016-01-01 03:00:00+00:00                    8295.00
# 2016-01-01 04:00:00+00:00                    7319.00
# ...                                              ...
# 2016-12-31 19:00:00+00:00                   15303.00
# 2016-12-31 20:00:00+00:00                   15354.00
# 2016-12-31 21:00:00+00:00                   14847.00
# 2016-12-31 22:00:00+00:00                   15056.00
# 2016-12-31 23:00:00+00:00                   15422.00
#
#                            DE_solar_generation_actual   v1   v2  v_50m   h1  \
# utc_timestamp
# 2016-01-01 00:00:00+00:00                        0.00 2.62 3.71   5.13 2.55
# 2016-01-01 01:00:00+00:00                        0.00 2.56 3.63   4.98 2.55
# 2016-01-01 02:00:00+00:00                        0.00 2.48 3.52   4.79 2.55
# 2016-01-01 03:00:00+00:00                        0.00 2.40 3.40   4.66 2.55
# 2016-01-01 04:00:00+00:00                        0.00 2.31 3.29   4.57 2.55
# ...                                               ...  ...  ...    ...  ...
# 2016-12-31 19:00:00+00:00                        0.00 3.68 5.23   7.10 2.55
# 2016-12-31 20:00:00+00:00                        0.00 3.76 5.31   7.08 2.55
# 2016-12-31 21:00:00+00:00                        0.00 3.79 5.34   7.12 2.55
# 2016-12-31 22:00:00+00:00                        0.00 3.85 5.42   7.22 2.55
# 2016-12-31 23:00:00+00:00                        0.00 3.88 5.46   7.28 2.55
#
#                              h2   z0  SWTDN  SWGDN  ...  humidity  dew  \
# utc_timestamp                                       ...
# 2016-01-01 00:00:00+00:00 10.55 0.16   0.00   0.00  ...    100.00 1.90
# 2016-01-01 01:00:00+00:00 10.55 0.16   0.00   0.00  ...     93.62 1.90
# 2016-01-01 02:00:00+00:00 10.55 0.16   0.00   0.00  ...     94.10 2.00
# 2016-01-01 03:00:00+00:00 10.55 0.16   0.00   0.00  ...     94.06 1.10
# 2016-01-01 04:00:00+00:00 10.55 0.16   0.00   0.00  ...     93.61 1.00
# ...                         ...  ...    ...    ...  ...       ...  ...
# 2016-12-31 19:00:00+00:00 10.55 0.16   0.00   0.00  ...     98.45 1.60
# 2016-12-31 20:00:00+00:00 10.55 0.16   0.00   0.00  ...     98.46 1.70
# 2016-12-31 21:00:00+00:00 10.55 0.16   0.00   0.00  ...     92.66 1.90
# 2016-12-31 22:00:00+00:00 10.55 0.16   0.00   0.00  ...     87.69 2.00
# 2016-12-31 23:00:00+00:00 10.55 0.16   0.00   0.00  ...     87.23 1.90
#
#                            windspeed  winddir  pressure  visibility  \
# utc_timestamp
# 2016-01-01 00:00:00+00:00       4.40   180.00       NaN        0.40
# 2016-01-01 01:00:00+00:00       5.60   196.00       NaN        0.30
# 2016-01-01 02:00:00+00:00       6.70   230.00       NaN        1.10
# 2016-01-01 03:00:00+00:00       5.10   218.00       NaN        1.30
# 2016-01-01 04:00:00+00:00       1.90   202.00       NaN        2.10
# ...                              ...      ...       ...         ...
# 2016-12-31 19:00:00+00:00      15.00   240.00       NaN        3.90
# 2016-12-31 20:00:00+00:00      14.20   239.00       NaN        4.30
# 2016-12-31 21:00:00+00:00      16.60   244.00       NaN        8.00
# 2016-12-31 22:00:00+00:00      13.20   226.00       NaN       10.00
# 2016-12-31 23:00:00+00:00      14.80   226.00       NaN       10.00
#
#                            cloudcover        conditions  skyType  \
# utc_timestamp
# 2016-01-01 00:00:00+00:00       98.40          Overcast     1.00
# 2016-01-01 01:00:00+00:00       59.20  Partially cloudy     2.00
# 2016-01-01 02:00:00+00:00       98.40          Overcast     1.00
# 2016-01-01 03:00:00+00:00       98.40          Overcast     1.00
# 2016-01-01 04:00:00+00:00       13.80             Clear     0.00
# ...                               ...               ...      ...
# 2016-12-31 19:00:00+00:00       98.40          Overcast     1.00
# 2016-12-31 20:00:00+00:00       98.40          Overcast     1.00
# 2016-12-31 21:00:00+00:00       98.40          Overcast     1.00
# 2016-12-31 22:00:00+00:00       98.40          Overcast     1.00
# 2016-12-31 23:00:00+00:00       98.40          Overcast     1.00
#
#                            total_renewable_generation
# utc_timestamp
# 2016-01-01 00:00:00+00:00                     8579.00
# 2016-01-01 01:00:00+00:00                     8542.00
# 2016-01-01 02:00:00+00:00                     8443.00
# 2016-01-01 03:00:00+00:00                     8295.00
# 2016-01-01 04:00:00+00:00                     7319.00
# ...                                               ...
# 2016-12-31 19:00:00+00:00                    15303.00
# 2016-12-31 20:00:00+00:00                    15354.00
# 2016-12-31 21:00:00+00:00                    14847.00
# 2016-12-31 22:00:00+00:00                    15056.00
# 2016-12-31 23:00:00+00:00                    15422.00
#
# [8711 rows x 24 columns]

# %%
train = weather[:6098] 
test = weather[6098:] 

X_solar_train = train[['SWTDN', 'SWGDN', 'T']]
y_solar_train = train['DE_solar_generation_actual']
X_solar_test = test[['SWTDN', 'SWGDN', 'T']]
y_solar_test = test['DE_solar_generation_actual']

X_wind_train = train[['v1', 'v2', 'v_50m', 'z0']]
y_wind_train = train['DE_wind_generation_actual']
X_wind_test = test[['v1', 'v2', 'v_50m', 'z0']]
y_wind_test = test['DE_wind_generation_actual']

# %%
solar_reg = LazyRegressor(verbose=0,ignore_warnings=True)
models, predictions = solar_reg.fit(X_solar_train, X_solar_test, y_solar_train, y_solar_test)
models
# Out:
#   0%|          | 0/42 [00:00<?, ?it/s]
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000316 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 765
# [LightGBM] [Info] Number of data points in the train set: 6098, number of used features: 3
# [LightGBM] [Info] Start training from score 4705.408331
#                                Adjusted R-Squared  R-Squared    RMSE  \
# Model
# HistGradientBoostingRegressor                0.93       0.93 1075.28
# LGBMRegressor                                0.93       0.93 1075.40
# XGBRegressor                                 0.93       0.93 1076.63
# PassiveAggressiveRegressor                   0.93       0.93 1091.96
# RANSACRegressor                              0.93       0.93 1093.64
# HuberRegressor                               0.93       0.93 1098.57
# RandomForestRegressor                        0.93       0.93 1108.30
# TransformedTargetRegressor                   0.93       0.93 1113.42
# LinearRegression                             0.93       0.93 1113.42
# LassoLarsIC                                  0.93       0.93 1113.42
# LarsCV                                       0.93       0.93 1113.42
# Lars                                         0.93       0.93 1113.42
# LassoLarsCV                                  0.93       0.93 1113.42
# OrthogonalMatchingPursuitCV                  0.93       0.93 1113.42
# BayesianRidge                                0.93       0.93 1113.48
# RidgeCV                                      0.93       0.93 1113.49
# Ridge                                        0.93       0.93 1114.12
# LassoLars                                    0.93       0.93 1114.16
# Lasso                                        0.93       0.93 1114.18
# SGDRegressor                                 0.92       0.93 1117.27
# LassoCV                                      0.92       0.92 1118.70
# BaggingRegressor                             0.92       0.92 1121.58
# ExtraTreesRegressor                          0.92       0.92 1127.87
# GradientBoostingRegressor                    0.92       0.92 1144.04
# OrthogonalMatchingPursuit                    0.92       0.92 1159.02
# GaussianProcessRegressor                     0.92       0.92 1172.76
# KNeighborsRegressor                          0.92       0.92 1174.03
# AdaBoostRegressor                            0.91       0.91 1204.41
# DecisionTreeRegressor                        0.90       0.90 1303.01
# ExtraTreeRegressor                           0.89       0.89 1370.81
# ElasticNet                                   0.84       0.84 1633.54
# MLPRegressor                                 0.78       0.78 1935.15
# TweedieRegressor                             0.77       0.77 1961.87
# PoissonRegressor                             0.65       0.65 2419.96
# LinearSVR                                    0.65       0.65 2425.47
# ElasticNetCV                                 0.22       0.22 3613.48
# SVR                                          0.21       0.21 3631.97
# NuSVR                                        0.05       0.05 3974.40
# QuantileRegressor                           -0.15      -0.15 4376.63
# DummyRegressor                              -0.39      -0.38 4803.94
# KernelRidge                                 -0.58      -0.57 5122.03
#
#                                Time Taken
# Model
# HistGradientBoostingRegressor        0.75
# LGBMRegressor                        0.14
# XGBRegressor                         0.56
# PassiveAggressiveRegressor           0.05
# RANSACRegressor                      0.07
# HuberRegressor                       0.09
# RandomForestRegressor                2.76
# TransformedTargetRegressor           0.02
# LinearRegression                     0.02
# LassoLarsIC                          0.04
# LarsCV                               0.05
# Lars                                 0.04
# LassoLarsCV                          0.04
# OrthogonalMatchingPursuitCV          0.04
# BayesianRidge                        0.08
# RidgeCV                              0.03
# Ridge                                0.02
# LassoLars                            0.02
# Lasso                                0.03
# SGDRegressor                         0.05
# LassoCV                              0.28
# BaggingRegressor                     0.39
# ExtraTreesRegressor                  1.28
# GradientBoostingRegressor            1.25
# OrthogonalMatchingPursuit            0.02
# GaussianProcessRegressor             8.65
# KNeighborsRegressor                  0.05
# AdaBoostRegressor                    0.60
# DecisionTreeRegressor                0.07
# ExtraTreeRegressor                   0.03
# ElasticNet                           0.03
# MLPRegressor                         5.12
# TweedieRegressor                     0.06
# PoissonRegressor                     0.02
# LinearSVR                            0.03
# ElasticNetCV                         0.23
# SVR                                  6.02
# NuSVR                                4.10
# QuantileRegressor                    2.11
# DummyRegressor                       0.02
# KernelRidge                          2.80

# %%
wind_reg = LazyRegressor(verbose=0,ignore_warnings=True)
models, predictions = wind_reg.fit(X_wind_train, X_wind_test, y_wind_train, y_wind_test)
models
# Out:
#   0%|          | 0/42 [00:00<?, ?it/s]
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000213 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1020
# [LightGBM] [Info] Number of data points in the train set: 6098, number of used features: 4
# [LightGBM] [Info] Start training from score 8334.015087
#                                Adjusted R-Squared  R-Squared       RMSE  \
# Model
# GradientBoostingRegressor                    0.90       0.90    2383.22
# ExtraTreesRegressor                          0.90       0.90    2393.15
# HistGradientBoostingRegressor                0.90       0.90    2406.22
# RandomForestRegressor                        0.90       0.90    2429.91
# BaggingRegressor                             0.89       0.89    2449.92
# LGBMRegressor                                0.89       0.89    2463.12
# XGBRegressor                                 0.88       0.88    2618.13
# KNeighborsRegressor                          0.88       0.88    2647.33
# SGDRegressor                                 0.88       0.88    2650.90
# LassoCV                                      0.88       0.88    2658.27
# AdaBoostRegressor                            0.87       0.87    2669.60
# Lasso                                        0.87       0.87    2670.75
# RANSACRegressor                              0.87       0.87    2675.82
# Ridge                                        0.87       0.87    2676.73
# LassoLars                                    0.87       0.87    2678.72
# OrthogonalMatchingPursuit                    0.87       0.87    2683.40
# RidgeCV                                      0.87       0.87    2684.49
# BayesianRidge                                0.87       0.87    2685.00
# OrthogonalMatchingPursuitCV                  0.87       0.87    2685.61
# LassoLarsIC                                  0.87       0.87    2685.61
# LassoLarsCV                                  0.87       0.87    2685.61
# TransformedTargetRegressor                   0.87       0.87    2685.61
# LinearRegression                             0.87       0.87    2685.61
# PassiveAggressiveRegressor                   0.87       0.87    2695.39
# HuberRegressor                               0.87       0.87    2721.23
# LarsCV                                       0.86       0.86    2801.98
# DecisionTreeRegressor                        0.86       0.86    2813.82
# ExtraTreeRegressor                           0.85       0.85    2874.03
# ElasticNet                                   0.79       0.79    3458.87
# PoissonRegressor                             0.79       0.79    3480.81
# TweedieRegressor                             0.73       0.73    3936.41
# GammaRegressor                               0.68       0.68    4266.61
# MLPRegressor                                 0.49       0.49    5390.12
# ElasticNetCV                                 0.38       0.38    5954.86
# LinearSVR                                    0.10       0.10    7136.80
# NuSVR                                        0.03       0.03    7431.65
# SVR                                          0.01       0.01    7511.57
# DummyRegressor                              -0.03      -0.03    7648.35
# QuantileRegressor                           -0.16      -0.16    8107.56
# KernelRidge                                 -0.72      -0.72    9881.43
# Lars                                      -158.73    -158.48   95226.44
# GaussianProcessRegressor                -21616.11  -21583.01 1107815.18
#
#                                Time Taken
# Model
# GradientBoostingRegressor            1.83
# ExtraTreesRegressor                  2.09
# HistGradientBoostingRegressor        0.49
# RandomForestRegressor                4.76
# BaggingRegressor                     0.48
# LGBMRegressor                        0.12
# XGBRegressor                         0.23
# KNeighborsRegressor                  0.05
# SGDRegressor                         0.13
# LassoCV                              0.21
# AdaBoostRegressor                    0.70
# Lasso                                0.05
# RANSACRegressor                      0.11
# Ridge                                0.02
# LassoLars                            0.06
# OrthogonalMatchingPursuit            0.03
# RidgeCV                              0.02
# BayesianRidge                        0.03
# OrthogonalMatchingPursuitCV          0.04
# LassoLarsIC                          0.02
# LassoLarsCV                          0.05
# TransformedTargetRegressor           0.03
# LinearRegression                     0.02
# PassiveAggressiveRegressor           0.05
# HuberRegressor                       0.05
# LarsCV                               0.03
# DecisionTreeRegressor                0.09
# ExtraTreeRegressor                   0.05
# ElasticNet                           0.02
# PoissonRegressor                     0.04
# TweedieRegressor                     0.02
# GammaRegressor                       0.03
# MLPRegressor                         5.27
# ElasticNetCV                         0.21
# LinearSVR                            0.02
# NuSVR                                4.46
# SVR                                  7.02
# DummyRegressor                       0.02
# QuantileRegressor                    2.32
# KernelRidge                          2.55
# Lars                                 0.06
# GaussianProcessRegressor             7.79

# %%
from sklearn.model_selection import cross_val_score
from sklearn.experimental import enable_hist_gradient_boosting
from sklearn.ensemble import HistGradientBoostingRegressor
hgbr = HistGradientBoostingRegressor()

# %%
X_solar = weather[['SWTDN', 'SWGDN', 'T']]
y_solar = weather['DE_solar_generation_actual']

scores_solar = cross_val_score(hgbr, X_solar, y_solar, cv=5)
print(scores_solar, "\naverage =", np.mean(scores_solar))
# Out:
# [0.85807896 0.94661228 0.94447233 0.95746803 0.88008925]
# average = 0.9173441664489002

# %%
hgbr = HistGradientBoostingRegressor().fit(X_solar_train, y_solar_train)

train_solar_pred = hgbr.predict(X_solar_train)
test_solar_pred = hgbr.predict(X_solar_test)


df = weather[['DE_solar_generation_actual']]

train_df = train[['DE_solar_generation_actual']]
train_df.loc[:, 'DE_solar_generation_actual'] = train_solar_pred

test_df = test[['DE_solar_generation_actual']]
test_df.loc[:, 'DE_solar_generation_actual'] = test_solar_pred


inversetransform, =plt.plot(df, label = 'Actual')
trainpredx, =plt.plot(train_df, color='orange', label = 'Train')
testpredx, =plt.plot(test_df, color='green', label = 'Test')
plt.xlabel('Date')
plt.ylabel('Solar Output')
plt.legend(loc="upper right")
plt.title("Predicted vs. Actual Solar Generation - HistGradBoosting")
plt.show()

# %%
metrics('histgrad', test['DE_solar_generation_actual'], test_solar_pred)
# Out:
#             MAE        MSE    RMSE  RMSLE   R2
# model
# histgrad 465.13 1156222.81 1075.28   6.98 0.93

# %%
from sklearn.ensemble import GradientBoostingRegressor
gbr = GradientBoostingRegressor()

# %%
X_wind = weather[['v1', 'v2', 'v_50m', 'z0']]
y_wind = weather['DE_wind_generation_actual']

scores_wind = cross_val_score(gbr, X_wind, y_wind, cv=5)
print(scores_wind, "\naverage =", np.mean(scores_wind))
# Out:
# [0.89845817 0.85054644 0.87858786 0.92984511 0.88913014]
# average = 0.8893135456479995

# %%
gbr = GradientBoostingRegressor().fit(X_wind_train, y_wind_train)

train_wind_pred = gbr.predict(X_wind_train)
test_wind_pred = gbr.predict(X_wind_test)

df = weather[['DE_wind_generation_actual']]

train_df = train[['DE_wind_generation_actual']]
train_df.loc[:, 'DE_wind_generation_actual'] = train_wind_pred

test_df = test[['DE_wind_generation_actual']]
test_df.loc[:, 'DE_wind_generation_actual'] = test_wind_pred

# Plot all predictions
inversetransform, =plt.plot(df, label = 'Actual')
trainpredx, =plt.plot(train_df, color='orange', label = 'Train')
testpredx, =plt.plot(test_df, color='green', label = 'Test')
plt.xlabel('Date')
plt.ylabel('wind Output')
plt.legend(loc="upper right")
plt.title("Predicted vs. Actual wind Generation - GradBoosting")
plt.show()

# %%
metrics('grad', test['DE_wind_generation_actual'], test_wind_pred)
# Out:
#           MAE        MSE    RMSE  RMSLE   R2
# model
# grad  1684.61 5634763.49 2373.77   7.77 0.90

# %%
from sklearn.model_selection import KFold 
from sklearn.metrics import r2_score
kf = KFold(n_splits=5, shuffle=True, random_state=1)

scores = []
for train_index, test_index in kf.split(weather):
    X_solar = weather.iloc[train_index, :][['SWTDN', 'SWGDN', 'T']]
    y_solar = weather.iloc[train_index, :]['DE_solar_generation_actual']
    hgbr = HistGradientBoostingRegressor().fit(X_solar, y_solar)

    X_wind = weather.iloc[train_index, :][['v1', 'v2', 'v_50m', 'z0']]
    y_wind = weather.iloc[train_index, :]['DE_wind_generation_actual']
    gbr = GradientBoostingRegressor().fit(X_wind, y_wind)
    
    scores.append(r2_score(
        hgbr.predict(weather.iloc[test_index, :][['SWTDN', 'SWGDN', 'T']]) + gbr.predict(weather.iloc[test_index, :][['v1', 'v2', 'v_50m', 'z0']]),
        weather.iloc[test_index, :]['DE_solar_generation_actual'] + weather.iloc[test_index, :]['DE_wind_generation_actual']))                

print(scores, "\naverage =", np.mean(scores))
# Out:
# [0.9475113984557924, 0.9406005982195693, 0.9394510510620339, 0.9452869616297337, 0.9366525401261084]
# average = 0.9419005098986476

# %%
class CustomRegressor:
    def __init__(self):
        self.solarRegressor = None
        self.windRegressor = None
        
    def fit(self, train_dataset):
        X_solar = train_dataset[['SWTDN', 'SWGDN', 'T']]
        y_solar = train_dataset['DE_solar_generation_actual']
        self.solarRegressor = HistGradientBoostingRegressor().fit(X_solar, y_solar)

        X_wind = train_dataset[['v1', 'v2', 'v_50m', 'z0']]
        y_wind = train_dataset['DE_wind_generation_actual']
        self.windRegressor = GradientBoostingRegressor().fit(X_wind, y_wind)
        return self
        
    def predict(self, prediction_dataset):
        return self.solarRegressor.predict(prediction_dataset[['SWTDN', 'SWGDN', 'T']]) + self.windRegressor.predict(prediction_dataset[['v1', 'v2', 'v_50m', 'z0']])

# %%
cr = CustomRegressor().fit(train)

train_total_pred = cr.predict(train)
test_total_pred = cr.predict(test)

df = weather[['DE_solar_generation_actual']]
df['Total Generation'] = weather['DE_solar_generation_actual'] + weather['DE_wind_generation_actual']
df.drop(['DE_solar_generation_actual'], axis = 1, inplace = True)

train_df = train[['DE_solar_generation_actual']]
train_df['Total Generation'] = train_total_pred
train_df.drop(['DE_solar_generation_actual'], axis = 1, inplace = True)

test_df = test[['DE_solar_generation_actual']]
test_df['Total Generation'] = test_total_pred
test_df.drop(['DE_solar_generation_actual'], axis = 1, inplace = True)

# Plot all predictions
inversetransform, =plt.plot(df, label = 'Actual')
trainpredx, =plt.plot(train_df, color='orange', label = 'Train')
testpredx, =plt.plot(test_df, color='green', label = 'Test')
plt.xlabel('Date')
plt.ylabel('Combined Output')
plt.legend(loc="upper right")
plt.title("Predicted vs. Actual wind + solar Generation - histgrad+grad")
plt.show()

# %%
metrics('histgrad+grad', test['DE_solar_generation_actual'] + test['DE_wind_generation_actual'], test_total_pred)
# Out:
#                   MAE        MSE    RMSE  RMSLE   R2
# model
# histgrad+grad 1980.47 7405861.89 2721.37   7.91 0.89
